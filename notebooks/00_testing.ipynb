# %%
import sys, platform
print("Python:", sys.version)
print("Platform:", platform.platform())
# Out:
# Python: 3.11.13 (main, Jun  5 2025, 08:14:07) [Clang 14.0.6 ]
# Platform: macOS-10.15.4-x86_64-i386-64bit

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression

print("numpy", np.__version__)
print("pandas", pd.__version__)
print("scipy", scipy.__version__)
print("statsmodels", sm.__version__)
# Out:
# numpy 2.0.1
# pandas 2.3.1
# scipy 1.16.0
# statsmodels 0.14.5

# %%
import pandas as pd

path = "../data/raw/"

df_main = pd.read_csv(path + "synthetic_mmm_weekly_india.csv")
df_sat  = pd.read_csv(path + "synthetic_mmm_weekly_india_SAT.csv")

# %%
print("Main dataset shape:", df_main.shape)
display(df_main.head())

print("\nSAT dataset shape:", df_sat.shape)
display(df_sat.head())
# Out:
# Main dataset shape: (11232, 28)
#          Week      Geo   Brand          SKU  Sales_Units   Sales_Value  \
# 0  2022-07-04  CENTRAL  BrandA  BrandA_SKU1   106.327944  10551.108260
# 1  2022-07-04  CENTRAL  BrandA  BrandA_SKU2   188.503304  19452.418311
# 2  2022-07-04  CENTRAL  BrandA  BrandA_SKU3   209.247921  19583.201537
# 3  2022-07-04  CENTRAL  BrandB  BrandB_SKU1   237.698249  19374.506591
# 4  2022-07-04  CENTRAL  BrandB  BrandB_SKU2   203.075116  14667.008092
#
#           MRP   Net_Price  Feature_Flag  Display_Flag  ...  \
# 0   99.231753   99.231753             0             0  ...
# 1  103.194045  103.194045             0             0  ...
# 2   93.588512   93.588512             0             0  ...
# 3   81.508832   81.508832             0             0  ...
# 4   72.224546   72.224546             0             0  ...
#
#    FB_Banner_Content_Score  IG_Banner_Content_Score  Weighted_Distribution  \
# ...

# %%
print("Main dataset columns:")
display(df_main.dtypes)

print("\nSAT dataset columns:")
display(df_sat.dtypes)
# Out:
# Main dataset columns:
# Week                        object
# Geo                         object
# Brand                       object
# SKU                         object
# Sales_Units                float64
# Sales_Value                float64
# MRP                        float64
# Net_Price                  float64
# Feature_Flag                 int64
# Display_Flag                 int64
# TPR_Flag                     int64
# Trade_Spend                float64
# TV_Impressions             float64
# YouTube_Impressions        float64
# Facebook_Impressions       float64
# Instagram_Impressions      float64
# Print_Readership           float64
# Radio_Listenership         float64
# FB_Banner_Content_Score    float64
# IG_Banner_Content_Score    float64
# Weighted_Distribution      float64
# Numeric_Distribution       float64
# TDP                        float64
# NOS                        float64
# CPI                        float64
# GDP_Growth                 float64
# ...

# %%
df_main.info()
df_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11232 entries, 0 to 11231
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Week                     11232 non-null  object
#  1   Geo                      11232 non-null  object
#  2   Brand                    11232 non-null  object
#  3   SKU                      11232 non-null  object
#  4   Sales_Units              11232 non-null  float64
#  5   Sales_Value              11232 non-null  float64
#  6   MRP                      11232 non-null  float64
#  7   Net_Price                11232 non-null  float64
#  8   Feature_Flag             11232 non-null  int64
#  9   Display_Flag             11232 non-null  int64
#  10  TPR_Flag                 11232 non-null  int64
#  11  Trade_Spend              11232 non-null  float64
#  12  TV_Impressions           11232 non-null  float64
#  13  YouTube_Impressions      11232 non-null  float64
# ...

# %%
df_main.describe().T
# Out:
#                            count          mean            std            min  \
# Sales_Units              11232.0  4.224323e+02     329.007914      25.535563
# Sales_Value              11232.0  3.309905e+04   27498.675570    2054.711829
# MRP                      11232.0  7.991171e+01      16.889088      52.759457
# Net_Price                11232.0  7.835360e+01      16.923665      46.696772
# Feature_Flag             11232.0  1.850962e-01       0.388393       0.000000
# Display_Flag             11232.0  1.834936e-01       0.387088       0.000000
# TPR_Flag                 11232.0  1.578526e-01       0.364619       0.000000
# Trade_Spend              11232.0  5.397700e+04   59637.303208    6140.424107
# TV_Impressions           11232.0  1.043587e+06  976845.497965  102622.706480
# YouTube_Impressions      11232.0  5.342054e+05  481418.836337   46338.661619
# Facebook_Impressions     11232.0  3.209519e+05  286317.802813   14170.185475
# ...

# %%
df_sat.describe().T
# Out:
#                            count          mean            std            min  \
# Sales_Units              11232.0  4.091443e+02     306.305614      29.971872
# Sales_Value              11232.0  3.245343e+04   27000.516407    2566.350247
# MRP                      11232.0  7.968707e+01      16.358434      52.906281
# Net_Price                11232.0  7.810849e+01      16.438529      46.028997
# Feature_Flag             11232.0  1.866987e-01       0.389687       0.000000
# Display_Flag             11232.0  1.842949e-01       0.387742       0.000000
# TPR_Flag                 11232.0  1.586538e-01       0.365369       0.000000
# Trade_Spend              11232.0  5.678406e+04   66045.213932    5326.099777
# TV_Impressions           11232.0  1.031174e+06  894503.466163  125119.839530
# YouTube_Impressions      11232.0  4.919045e+05  405251.737867   39180.104578
# Facebook_Impressions     11232.0  3.890921e+05  336988.735427   36922.478257
# ...
